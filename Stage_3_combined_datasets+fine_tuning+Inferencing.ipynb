# %%
# Installs Unsloth, Xformers (Flash Attention) and all other packages!
# !pip install "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git"
# !pip install --no-deps xformers "trl<0.9.0" peft accelerate bitsandbytes
# Out:
# ...
#   Cloning https://github.com/unslothai/unsloth.git to /tmp/pip-install-jalpy9pd/unsloth_54f656867a8b4689b4a391642894e0c6
#   Running command git clone --filter=blob:none --quiet https://github.com/unslothai/unsloth.git /tmp/pip-install-jalpy9pd/unsloth_54f656867a8b4689b4a391642894e0c6
#   Resolved https://github.com/unslothai/unsloth.git to commit 172219e3e76e5508e97da3e5e281597a4246dcb7
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# Load the first CSV file
file_path1 = '/content/drive/MyDrive/1-Working/1-HSLU-MscIDS/5-Projects/4-Semester/CLT/Samuel-CLT-Development/patent_qa_pairs_processed.csv'
df1 = pd.read_csv(file_path1)

# Load the second CSV file
file_path2 = '/content/drive/MyDrive/1-Working/1-HSLU-MscIDS/5-Projects/4-Semester/CLT/Samuel-CLT-Development/media_qa_pairs_processed.csv'
df2 = pd.read_csv(file_path2)

# Combine the two DataFrames
combined_df = pd.concat([df1, df2], ignore_index=True)

# Optionally, save the combined DataFrame to a new CSV file
output_path = '/content/drive/MyDrive/1-Working/1-HSLU-MscIDS/5-Projects/4-Semester/CLT/Samuel-CLT-Development/combined_qa_pairs.csv'
combined_df.to_csv(output_path, index=False)

# Display the head of the combined DataFrame to verify
print(combined_df.head())
# Out:
#                                               answer  \
# 0  Disclosed is an adaptable DC-AC inverter syste...
# 1  A solar energy system comprises: a solar energ...
# 2  A control method for optimizing a solar-to-pow...
# 3  The system includes a first hydropower system,...
# 4  A system and method for driving geese away fro...
#
#                                             question  \
# 0  What are the advantages of the proposed adapti...
# 1  What components are included in a typical sola...
# 2  What control method is proposed for optimizing...
# 3  How are the waterwheels and hoist devices in t...
# 4  What is the principle behind the system that u...
#
#                                                 text
# 0  \n<s> \nYou are a helpful assistant to the use...
# 1  \n<s> \nYou are a helpful assistant to the use...
# 2  \n<s> \nYou are a helpful assistant to the use...
# 3  \n<s> \nYou are a helpful assistant to the use...
# 4  \n<s> \nYou are a helpful assistant to the use...

# %%
import pandas as pd

# Assuming combined_df is your combined DataFrame

# Randomize the rows of the DataFrame
randomized_df = combined_df.sample(frac=1).reset_index(drop=True)

# Optionally, save the randomized DataFrame to a new CSV file
output_path = '/content/drive/MyDrive/1-Working/1-HSLU-MscIDS/5-Projects/4-Semester/CLT/Samuel-CLT-Development/randomized_qa_pairs.csv'
randomized_df.to_csv(output_path, index=False)

# Display the head of the randomized DataFrame to verify
print(randomized_df.head())
# Out:
#                                               answer  \
# 0  A team led by University of South Australia re...
# 1  Polyester basement membrane for solar energy b...
# 2  Lithium-ion batteries are ubiquitous, whether ...
# 3  US-based Revkor Energy Holdings Inc and German...
# 4  The utility model discloses a lighting device ...
#
#                                             question  \
# 0  What are the key advantages of the new soil po...
# 1  What are the functions and advantages of using...
# 2  How are the sales of lithium-ion batteries exp...
# 3  What is the planned annual production capacity...
# 4  What components are included in the utility mo...
#
#                                                 text
# 0  \n<s> \nYou are a helpful assistant to the use...
# 1  \n<s> \nYou are a helpful assistant to the use...
# 2  \n<s> \nYou are a helpful assistant to the use...
# 3  \n<s> \nYou are a helpful assistant to the use...
# 4  \n<s> \nYou are a helpful assistant to the use...

# %%
import pandas as pd
# Load the combined CSV file
file_path = '/content/drive/MyDrive/1-Working/1-HSLU-MscIDS/5-Projects/4-Semester/CLT/Samuel-CLT-Development/randomized_qa_pairs.csv'
dataset = pd.read_csv(file_path)
dataset.iloc[0]
# Out:
# answer      A team led by University of South Australia re...
# question    What are the key advantages of the new soil po...
# text        \n<s> \nYou are a helpful assistant to the use...
# Name: 0, dtype: object

# %%
dataset.head()
# Out:
#                                               answer  \
# 0  A team led by University of South Australia re...
# 1  Polyester basement membrane for solar energy b...
# 2  Lithium-ion batteries are ubiquitous, whether ...
# 3  US-based Revkor Energy Holdings Inc and German...
# 4  The utility model discloses a lighting device ...
#
#                                             question  \
# 0  What are the key advantages of the new soil po...
# 1  What are the functions and advantages of using...
# 2  How are the sales of lithium-ion batteries exp...
# 3  What is the planned annual production capacity...
# 4  What components are included in the utility mo...
#
#                                                 text
# 0  \n<s> \nYou are a helpful assistant to the use...
# 1  \n<s> \nYou are a helpful assistant to the use...
# 2  \n<s> \nYou are a helpful assistant to the use...
# 3  \n<s> \nYou are a helpful assistant to the use...
# 4  \n<s> \nYou are a helpful assistant to the use...

# %%
# Import Dataset class from the datasets package
from datasets import Dataset
# Convert the DataFrame to a Hugging Face Dataset
dataset = Dataset.from_pandas(dataset)

# %%
 dataset
# Out:
# Dataset({
#     features: ['answer', 'question', 'text'],
#     num_rows: 12319
# })

# %%
dataset[0]
# Out:
# {'answer': 'A team led by University of South Australia researchers has pioneered a new soil remediation technique. The technique is significantly faster, simpler, safer, and more cost-effective than currently available methods. UN report identifies soil pollution as a major threat to the global production of safe and sufficient food.',
#  'question': 'What are the key advantages of the new soil pollution detection technique developed by the University of South Australia team compared to existing methods?',
# ...

# %%
dataset[1]
# Out:
# {'answer': 'Polyester basement membrane for solar energy backplate includes tie coat and base member layer. The polyester base film has excellent mechanical property and excellent bonding force with a solar cell packaging adhesive film. It can be used as a bonding layer and a supporting body layer of a solar backboard.',
#  'question': 'What are the functions and advantages of using a polyester basement membrane in solar energy backboards, considering its mechanical properties and bonding capabilities with solar cell packaging adhesives?',
# ...

# %%
print(dataset[0]["text"])
# Out:
# <s>
# You are a helpful assistant to the user.
# >>> human: What are the key advantages of the new soil pollution detection technique developed by the University of South Australia team compared to existing methods?
# >>> gpt: A team led by University of South Australia researchers has pioneered a new soil remediation technique. The technique is significantly faster, simpler, safer, and more cost-effective than currently available methods. UN report identifies soil pollution as a major threat to the global production of safe and sufficient food.

# %%
from unsloth import FastLanguageModel
import torch
max_seq_length = 2048 # Choose any
dtype = None # None for auto detection. Float16 for Tesla T4, V100, Bfloat16 for Ampere+
load_in_4bit = True # Use 4bit quantization to reduce memory usage. Can be False.


model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "unsloth/Phi-3-mini-4k-instruct", # Choose ANY! eg teknium/OpenHermes-2.5-Mistral-7B
    max_seq_length = max_seq_length,
    dtype = dtype,
    load_in_4bit = load_in_4bit,
    # token = "hf_...", # use one if using gated models like meta-llama/Llama-2-7b-hf
)
# Out:
# config.json:   0%|          | 0.00/1.16k [00:00<?, ?B/s]
# ==((====))==  Unsloth: Fast Mistral patching release 2024.5
#    \\   /|    GPU: Tesla T4. Max memory: 14.748 GB. Platform = Linux.
# O^O/ \_/ \    Pytorch: 2.3.0+cu121. CUDA = 7.5. CUDA Toolkit = 12.1.
# \        /    Bfloat16 = FALSE. Xformers = 0.0.26.post1. FA = False.
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# model.safetensors:   0%|          | 0.00/2.26G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/172 [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
model = FastLanguageModel.get_peft_model(
    model,
    r = 16, # Choose any number > 0 ! Suggested 8, 16, 32, 64, 128
    target_modules = ["q_proj", "k_proj", "v_proj", "o_proj",
                      "gate_proj", "up_proj", "down_proj",],
    lora_alpha = 16,
    lora_dropout = 0, # Supports any, but = 0 is optimized
    bias = "none",    # Supports any, but = "none" is optimized
    # [NEW] "unsloth" uses 30% less VRAM, fits 2x larger batch sizes!
    use_gradient_checkpointing = "unsloth", # True or "unsloth" for very long context
    random_state = 3407,
    use_rslora = False,  # We support rank stabilized LoRA
    loftq_config = None, # And LoftQ
)

# %% [markdown]
# <a name="Train"></a>
# ### Train the model
# Now let's use Huggingface TRL's `SFTTrainer`!

# %%
from trl import SFTTrainer
from transformers import TrainingArguments
from unsloth import is_bfloat16_supported

trainer = SFTTrainer(
    model = model,
    tokenizer = tokenizer,
    train_dataset = dataset,
    dataset_text_field = "text",
    max_seq_length = max_seq_length,
    dataset_num_proc = 2,
    packing = False, # Can make training 5x faster for short sequences.
    args = TrainingArguments(
        per_device_train_batch_size = 2,
        gradient_accumulation_steps = 4,
        warmup_steps = 5,
        #max_steps = 60,
        num_train_epochs =1, # Can be trained longer for better results
        learning_rate = 2e-4,
        fp16 = not is_bfloat16_supported(),
        bf16 = is_bfloat16_supported(),
        logging_steps = 1,
        optim = "adamw_8bit",
        weight_decay = 0.01,
        lr_scheduler_type = "linear",
        seed = 3407,
        output_dir = "outputs",
    ),
)
# Out:
# /usr/local/lib/python3.10/dist-packages/multiprocess/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# Map (num_proc=2):   0%|          | 0/12319 [00:00<?, ? examples/s]

# %%
#@title Show current memory stats
gpu_stats = torch.cuda.get_device_properties(0)
start_gpu_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
max_memory = round(gpu_stats.total_memory / 1024 / 1024 / 1024, 3)
print(f"GPU = {gpu_stats.name}. Max memory = {max_memory} GB.")
print(f"{start_gpu_memory} GB of memory reserved.")
# Out:
# GPU = Tesla T4. Max memory = 14.748 GB.
# 9.484 GB of memory reserved.

# %%
trainer_stats = trainer.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs = 1
#    \\   /|    Num examples = 12,319 | Num Epochs = 1
# O^O/ \_/ \    Batch size per device = 2 | Gradient Accumulation steps = 4
# \        /    Total batch size = 8 | Total steps = 1,540
#  "-____-"     Number of trainable parameters = 29,884,416
#     <div>
#
#       <progress value='1229' max='1540' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1229/1540 58:43 < 14:53, 0.35 it/s, Epoch 0.80/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>3.010400</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>3.102600</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.653400</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.619100</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %%
#@title Show final memory and time stats
used_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
used_memory_for_lora = round(used_memory - start_gpu_memory, 3)
used_percentage = round(used_memory         /max_memory*100, 3)
lora_percentage = round(used_memory_for_lora/max_memory*100, 3)
print(f"{trainer_stats.metrics['train_runtime']} seconds used for training.")
print(f"{round(trainer_stats.metrics['train_runtime']/60, 2)} minutes used for training.")
print(f"Peak reserved memory = {used_memory} GB.")
print(f"Peak reserved memory for training = {used_memory_for_lora} GB.")
print(f"Peak reserved memory % of max memory = {used_percentage} %.")
print(f"Peak reserved memory for training % of max memory = {lora_percentage} %.")

# %% [markdown]
# <a name="Inference"></a>
# ### Inference Testing
# Let's run the model! Since we're using `Phi-3`, use `apply_chat_template` with `add_generation_prompt` set to `True` for inference.

# %%
from unsloth.chat_templates import get_chat_template

tokenizer = get_chat_template(
    tokenizer,
    chat_template = "phi-3", # Supports zephyr, chatml, mistral, llama, alpaca, vicuna, vicuna_old, unsloth
    mapping = {"role" : "from", "content" : "value", "user" : "human", "assistant" : "gpt"}, # ShareGPT style
)

FastLanguageModel.for_inference(model) # Enable native 2x faster inference

# TEST QUESTION
messages = [
    {"from": "human", "value": "What components are included in a high-efficiency thermal drying system for drying purposes?"},
]
inputs = tokenizer.apply_chat_template(
    messages,
    tokenize = True,
    add_generation_prompt = True, # Must add for generation
    return_tensors = "pt",
).to("cuda")

# MAX NEW TOKENS DETERMINES THE LENGTH OF THE OUTPUT
outputs = model.generate(input_ids = inputs, max_new_tokens = 100, use_cache = True)
response=tokenizer.batch_decode(outputs)

# %%
# Print the generated response
print(response[0])
# Out:
# <s><|user|> What components are included in a high-efficiency thermal drying system for drying purposes?<|end|><|assistant|> A high-efficiency thermal drying system for drying purposes typically includes the following components:
#
# 1. A drying chamber: This is the main component where the drying process takes place. It is designed to provide a controlled environment for drying materials.
#
# 2. A heating element: This component generates heat to facilitate the drying process. It can be powered by electricity, natural gas, or other energy sources.
#
# 3. A heat ex

# %%
print(response[0].split('<|assistant|>')[-1])
# Out:
#  A high-efficiency thermal drying system for drying purposes typically includes the following components:
#
# 1. A drying chamber: This is the main component where the drying process takes place. It is designed to provide a controlled environment for drying materials.
#
# 2. A heating element: This component generates heat to facilitate the drying process. It can be powered by electricity, natural gas, or other energy sources.
#
# 3. A heat ex

# %% [markdown]
# ### GENERATING ANSWERS TO SAMPLE MEDIATECH QUESTIONS USING OUR FINETUNED PHI3-MINI

# %%
# List of questions
questions = [
    "What components make up the emergency power supply function of the FTU?",
    "How does the adjustable height feature of the energy-saving intelligent street lamp work?",
    "How does the BP neural network-based composite heating control system achieve energy efficiency?",
    "What is the primary function of the excitation-enhanced ocean current energy generating system?",
    "How does the real-time monitoring device enhance safety in the nuclear power plant control system?",
    "What are the key components and design features of the adjustable airflow ventilation system?",
    "How much did the U.S. rig count increase in the week ended April 29 compared to the same period last year?",
    "What is the expected annual reduction in CO2 emissions from the planned 20-kilometer geothermal heat network in Pantin, Les Lilas, and Pré-Saint-Gervais, and which types of buildings will benefit from this initiative?",
    "What was the percentage decrease in the February Nymex gas futures contract from the previous day's close, and how did the actual withdrawal of natural gas from storage for the final week of 2021 compare to expectations?",
    "How does the Auxiliary Sail Propulsion System (ASPS) utilize fixed wing sail technology and the rotation of masts to harness wind power for propulsion?",
    "What was the total amount of new energy storage systems brought online in Q4 2020 in the U.S., and which state had the majority of these deployments?",
    "What was the total amount of new funds raised by startups in the first half of 2022?",
]

# %%
from unsloth.chat_templates import get_chat_template

# Initialize the tokenizer with the required chat template
tokenizer = get_chat_template(
    tokenizer,
    chat_template = "phi-3",
    mapping = {"role" : "from", "content" : "value", "user" : "human", "assistant" : "gpt"}
)

# Set the model for faster inference
FastLanguageModel.for_inference(model)



# Function to process each question and generate a response
def generate_response(question):
    messages = [{"from": "human", "value": question}]
    inputs = tokenizer.apply_chat_template(
        messages,
        tokenize=True,
        add_generation_prompt=True,
        return_tensors="pt",
    ).to("cuda")

    # Pass the entire tensor directly to model.generate, as verified from your provided code
    outputs = model.generate(input_ids=inputs, max_new_tokens=300, use_cache=True)
    response = tokenizer.batch_decode(outputs, skip_special_tokens=True)
    return response[0]

# Generate responses for each question
responses = [generate_response(q) for q in questions]

# Print each question with its response
for question, response in zip(questions, responses):
    print(f"Question: {question}\nResponse: {response}\n")
# Out:
# Question: What components make up the emergency power supply function of the FTU?
# Response: What components make up the emergency power supply function of the FTU? The emergency power supply function of the FTU comprises the following components:
#
# 1. The emergency power supply is connected to the FTU through a power supply cable.
# 2. The FTU is equipped with a power supply module, which is responsible for converting the emergency power supply into usable power for the FTU.
# 3. The FTU also includes a power management module, which regulates and distributes the power generated by the power supply module.
# 4. The FTU is further equipped with a power storage module, which stores excess power generated by the power supply module for later use.
# 5. The FTU is connected to the power grid through a power grid connection module, allowing it to draw power from the grid when necessary.
# ...

# %%
import pandas as pd

# Assuming `questions` and `responses` are your lists of questions and their corresponding responses
data = {
    "Question": questions,
    "Finetuned-Phi3-Answers": responses
}

# Create a DataFrame using the data dictionary
df = pd.DataFrame(data)

# %%
df
# Out:
#                                              Question  \
# 0   What components make up the emergency power su...
# 1   How does the adjustable height feature of the ...
# 2   How does the BP neural network-based composite...
# 3   What is the primary function of the excitation...
# 4   How does the real-time monitoring device enhan...
# 5   What are the key components and design feature...
# 6   How much did the U.S. rig count increase in th...
# 7   What is the expected annual reduction in CO2 e...
# 8   What was the percentage decrease in the Februa...
# 9   How does the Auxiliary Sail Propulsion System ...
# 10  What was the total amount of new energy storag...
# 11  What was the total amount of new funds raised ...
#
#                                Finetuned-Phi3-Answers
# 0   What components make up the emergency power su...
# 1   How does the adjustable height feature of the ...
# 2   How does the BP neural network-based composite...
# ...

# %%
# Save to csv
df.to_csv("/content/drive/MyDrive/1-Working/1-HSLU-MscIDS/5-Projects/4-Semester/CLT/Samuel-CLT-Development/Finetuned-Phi3-Answers.csv", index=False)

# %% [markdown]
# <a name="Save"></a>
# ### Saving models

# %%
from google.colab import drive
from unsloth import FastLanguageModel

# Define the directory to save the GGUF quantized model
save_directory = '/content/drive/MyDrive/1-Working/1-HSLU-MscIDS/5-Projects/4-Semester/CLT/Samuel-CLT-Development/SAM-MAHA-phi3mini-Cleantech-Finetune-GGUF_Epoch_2_q4/GGUF_Epoch_2_q4_model'
# gguf_model_directory = f"{save_directory}/GGUF_Epoch_2_q4_model"

# # Create the directory if it does not exist
# import os
# if not os.path.exists(gguf_model_directory):
#     os.makedirs(gguf_model_directory)

# Save the model with GGUF quantization
try:
    model.save_pretrained_gguf(save_directory, tokenizer, quantization_method="q4_k_m")
    print("Model saved successfully with GGUF quantization.")
except Exception as e:
    print(f"An error occurred while saving the GGUF model: {e}")

# # Check the contents of the directory to verify the save
# print("Files in GGUF model directory:", os.listdir(gguf_model_directory))
# Out:
# Unsloth: Merging 4bit and LoRA weights to 16bit...
# Unsloth: Will use up to 7.29 out of 12.67 RAM for saving.
# 100%|██████████| 32/32 [00:01<00:00, 28.56it/s]
# Unsloth: Saving tokenizer... Done.
# Unsloth: Saving model... This might take 5 minutes for Llama-7b...
# Unsloth: Saving /content/drive/MyDrive/1-Working/1-HSLU-MscIDS/5-Projects/4-Semester/CLT/Samuel-CLT-Development/SAM-MAHA-phi3mini-Cleantech-Finetune-GGUF_Epoch_2_q4/GGUF_Epoch_2_q4_model/pytorch_model-00001-of-00002.bin...
# Unsloth: Saving /content/drive/MyDrive/1-Working/1-HSLU-MscIDS/5-Projects/4-Semester/CLT/Samuel-CLT-Development/SAM-MAHA-phi3mini-Cleantech-Finetune-GGUF_Epoch_2_q4/GGUF_Epoch_2_q4_model/pytorch_model-00002-of-00002.bin...
# Done.
# Unsloth: ##### The current model type of mistral auto adds a BOS token.
# Unsloth: ##### If you're using Ollama or GGUF etc, do not add a BOS in the chat template.
# ...
