# %% [markdown]
# # Loading the Dataset
#
# Load the dataset from the specified file path and inspect the first few entries:

# %%
import pandas as pd

# %%
# Load the dataset
file_path = "patent_preprocessed.csv"
patent_data = pd.read_csv(file_path)

# %%
print(patent_data.shape)
patent_data[["title", "abstract"]].head(10)
# Out:
# (8545, 12)
#                                                title  \
# 0  Adaptable DC-AC Inverter Drive System and Oper...
# 1  System for providing the energy from a single ...
# 2      Verfahren zum steuern einer windenergieanlage
# 3  Control method for optimizing solar-to-power e...
# 4             Mutually supporting hydropower systems
# 5              System and Method to Drive Away Geese
# 6                                     Cladding sheet
# 7             Hardened solar energy collector system
# 8  Systems and methods for hydro-based electric p...
# 9  Systems and methods for removing dust from sol...
#
#                                             abstract
# 0  Disclosed is an adaptable DC-AC inverter syste...
# 1  In accordance with an example embodiment, a so...
# 2  Verfahren zum Steuern einer Windenergieanlage ...
# 3  A control method for optimizing a solar-to-pow...
# 4  The mutually supporting hydropower systems inc...
# 5  A system and method for driving geese away fro...
# 6  Cladding sheets (9), such as roof or wall clad...
# 7  A hardened solar thermal energy collector (STE...
# 8  A hydrodynamic power generation assembly and m...
# 9  Presented herein are systems and methods for w...

# %%
patent_data.head(4)
# Out:
#   publication_number application_number country_code publication_date  \
# 0   US-2022239235-A1  US-202217717397-A           US       2022-07-28
# 1   US-2022239251-A1  US-202217580956-A           US       2022-07-28
# 2      EP-4033090-A1      EP-21152924-A           EP       2022-07-27
# 3     US-11396827-B2  US-202117606042-A           US       2022-07-26
#
#                                                title  \
# 0  Adaptable DC-AC Inverter Drive System and Oper...
# 1  System for providing the energy from a single ...
# 2      Verfahren zum steuern einer windenergieanlage
# 3  Control method for optimizing solar-to-power e...
#
#                                             abstract  \
# 0  Disclosed is an adaptable DC-AC inverter syste...
# 1  In accordance with an example embodiment, a so...
# 2  Verfahren zum Steuern einer Windenergieanlage ...
# 3  A control method for optimizing a solar-to-pow...
#
#                                            inventors        code  inventive  \
# 0                                                 []  H02M7/5395       True
# 1                                                 []   H02S40/38       True
# 2  ['Schaper, Ulf', 'von Aswege, Enno', 'Gerke Fu...  F03D7/0276       True
# 3                                                 []   F24S50/00       True
#
#    first                                 title_preprocessed  \
# 0  False    adaptable dc ac inverter drive system operation
# 1  False  system provide energy single contiguous solar ...
# 2   True      verfahren zum steuern einer windenergieanlage
# 3  False  control method optimize solar power efficiency...
#
#                                abstract_preprocessed
# 0  disclose adaptable dc ac inverter system opera...
# 1  accordance example embodiment solar energy sys...
# 2  verfahren zum steuern einer windenergieanlage ...
# 3  control method optimize solar power efficiency...

# %% [markdown]
# ### Filter out all all abstracts which are not english

# %%
import pandas as pd
from langdetect import detect, LangDetectException

# Assuming you have a DataFrame named patent_data
# patent_data = pd.read_csv('your_patent_data.csv')  # Load your DataFrame


def is_english(text):
    try:
        return detect(text) == "en"
    except LangDetectException:
        return False


# Apply the function to filter rows where abstracts are in English
patent_data_english = patent_data[patent_data["abstract"].apply(is_english)]

# Save the filtered DataFrame to a new CSV file
patent_data_english.to_csv("patent_data_english.csv", index=False)

# %%
# Display the filtered DataFrame
print("\nFiltered DataFrame (Only English Abstracts):")
print(patent_data_english.shape)
patent_data_english.head()
# Out:
# Filtered DataFrame (Only English Abstracts):
# (4301, 12)
#   publication_number application_number country_code publication_date  \
# 0   US-2022239235-A1  US-202217717397-A           US       2022-07-28
# 1   US-2022239251-A1  US-202217580956-A           US       2022-07-28
# 3     US-11396827-B2  US-202117606042-A           US       2022-07-26
# 4   US-2022228549-A1  US-202117153853-A           US       2022-07-21
# 5   US-2022225606-A1  US-202217714484-A           US       2022-07-21
#
#                                                title  \
# 0  Adaptable DC-AC Inverter Drive System and Oper...
# 1  System for providing the energy from a single ...
# 3  Control method for optimizing solar-to-power e...
# 4             Mutually supporting hydropower systems
# 5              System and Method to Drive Away Geese
#
#                                             abstract  \
# 0  Disclosed is an adaptable DC-AC inverter syste...
# 1  In accordance with an example embodiment, a so...
# 3  A control method for optimizing a solar-to-pow...
# 4  The mutually supporting hydropower systems inc...
# 5  A system and method for driving geese away fro...
#
#                                 inventors        code  inventive  first  \
# 0                                      []  H02M7/5395       True  False
# 1                                      []   H02S40/38       True  False
# 3                                      []   F24S50/00       True  False
# 4                     ['CHEN, CHUN-HUEI']    F03B3/00       True  False
# 5  ['KOVARIK, JOSEPH E.', 'FRANEK, JEFF']   A01M29/10       True   True
#
#                                   title_preprocessed  \
# 0    adaptable dc ac inverter drive system operation
# 1  system provide energy single contiguous solar ...
# 3  control method optimize solar power efficiency...
# 4                 mutually support hydropower system
# 5                     system method drive away geese
#
#                                abstract_preprocessed
# 0  disclose adaptable dc ac inverter system opera...
# 1  accordance example embodiment solar energy sys...
# 3  control method optimize solar power efficiency...
# 4  mutually support hydropower system include hyd...
# 5  system method drive geese away area employ pre...

# %% [markdown]
# ### Summarize the abstracts

# %%
from transformers import pipeline
import tqdm

# Load your dataset
patent_data_english = pd.read_csv("patent_data_english.csv")

# Initialize the summarizer
summarizer = pipeline("summarization", model="facebook/bart-large-cnn")


# Function to summarize a batch of texts
def summarize_batch(texts, batch_size=8):
    summaries = []
    for i in tqdm.tqdm(range(0, len(texts), batch_size)):
        batch = texts[i: i + batch_size]
        try:
            # Ensure texts are not too long for the summarizer
            batch = [text[:1000] for text in batch]
            batch_summaries = summarizer(
                batch, max_length=130, min_length=30, do_sample=False
            )
            summaries.extend([summary["summary_text"]
                             for summary in batch_summaries])
        except Exception as e:
            summaries.extend(
                [""] * len(batch)
            )  # Extend with empty summaries in case of an error
            print(f"Error in batch {i // batch_size}: {e}")
    return summaries


# Process a single chunk of the data
chunk_size = 50  # Define the size of the chunk
data_chunk = media_data.head(chunk_size).copy()  # Get the first chunk of data

# Summarize the content column of the data chunk
summaries = summarize_batch(data_chunk["content"].tolist())

# Apply the summaries to the DataFrame
data_chunk.loc[:, "summary"] = summaries

# Display the first few rows of the data chunk with the summaries
print(data_chunk[["title", "summary"]].head())
# Out:
# 100%|██████████| 7/7 [04:58<00:00, 42.71s/it]
#                                                title  \
# 0  Qatar to Slash Emissions as LNG Expansion Adva...
# 1               India Launches Its First 700 MW PHWR
# 2              New Chapter for US-China Energy Trade
# 3  Japan: Slow Restarts Cast Doubt on 2030 Energy...
# 4     NYC Pension Funds to Divest Fossil Fuel Shares
#
#                                              summary
# 0  Qatar Petroleum ( QP) is targeting aggressive ...
# 1  Kakrapar-3 is the first of India's 700 megawat...
# 2  New US President Joe Biden took office this we...
# 3  The slow pace of Japanese reactor restarts con...
# 4  Two of New York City's largest pension funds s...

# %%
# check the summary
data_chunk[["title", "summary"]].head(50)
# Out:
#                                                 title  \
# 0   Qatar to Slash Emissions as LNG Expansion Adva...
# 1                India Launches Its First 700 MW PHWR
# 2               New Chapter for US-China Energy Trade
# 3   Japan: Slow Restarts Cast Doubt on 2030 Energy...
# 4      NYC Pension Funds to Divest Fossil Fuel Shares
# 5   Japan: Supreme Court Will Likely Decide on Fuk...
# 6      Biden Appointees Signal Progressive Engagement
# 7              The Big Picture: The New 'Great Game '
# 8   Japan: Tritium Release Plans at Fukushima On Hold
# 9   United States: Cold Snap Highlights Electrific...
# 10     Taiwan: Kuosheng-1 Headed for Early Retirement
# 11  Corporate: Exelon Splits Generation from Trans...
# 12  Europe Targets Synthetic SAF Production for Lo...
# 13               Carbon Management at Your 'Service '
# 14     Santos Sanctions Barossa-to-Darwin LNG Project
# 15  United States: Biden Looks to Spend Big on Cle...
# 16  US Airlines Chart Flight Path to Net-Zero Emis...
# 17  United States: Biden Folds Nuclear Into Infras...
# 18         Oil Traders Map Out Energy Transition Role
# 19                      Oil Is Vital to Decarbonizing
# 20      Taiwan: Tsai Pushes to Defeat Lungmen Revival
# 21            Investors Try to Make Sense of Net-Zero
# 22           Exxon Suffers Another Guyana Gas Problem
# 23  Pipelines Eye New Ways to Advance Energy Trans...
# 24                       Majors Embrace Offshore Wind
# 25               Pipelines Adapt to Energy Transition
# 26                  BlackRock Aims to Beat Benchmarks
# 27  Capturing the Moment: Carbon Capture in the Am...
# 28          Climate: US Summit Short on Deliverables?
# 29             Hydrogen's Waiting Game: Now or Never?
# 30      EU Recovery Plans Would Accelerate Transition
# 31        Renewable Power Secures Permanent Cost Lead
# 32        Shell Resets Refining for Energy Transition
# 33                 Repsol Enters US Renewables Market
# 34               Offsets Face Scrutiny as ESG Evolves
# 35  Outlook: IEA Sees Nuclear as 'Essential Founda...
# 36          Climate Shifts Forcefully Against Big Oil
# 37  Chevron Shareholder Vote Increases Climate Pre...
# 38               Japan: Meti's Bullish Back-End Plans
# 39                 Orsted's Green Plans Lag Its Peers
# 40  United States: Biden's Proposed Nuclear Spendi...
# 41          Repsol Exec Hypes US Renewables Potential
# 42  Japan’ s Astomos Signs with Shell for Carbon-N...
# 43            Euro Majors Take Aim at US Green Market
# 44       Our Take: Renewables Trade Returns for Scale
# 45  Generation: China Power Conundrum Threatens Cl...
# 46                   BP Says Russia Fits Its Strategy
# 47  Carolinas Wrestle Over Duke's Future Plans for...
# 48  United Kingdom: NDA Takes on AGR Decommissionings
# 49             Shale Holds Line Despite Rising Prices
#
#                                               summary
# 0   Qatar Petroleum ( QP) is targeting aggressive ...
# 1   Kakrapar-3 is the first of India's 700 megawat...
# 2   New US President Joe Biden took office this we...
# 3   The slow pace of Japanese reactor restarts con...
# 4   Two of New York City's largest pension funds s...
# 5   Japan's Supreme Court will likely become the a...
# 6   Oil and natural gas industry officials have be...
# 7   Low-carbon energy race will be at the center a...
# 8   Plans to deal with more than 1 million tons of...
# 9   The coldest weather in a generation brought wi...
# 10  Taiwan Power Co. ( Taipower) is retiring its 9...
# 11  Exelon's plans to split its nuclear-dominated ...
# 12  Europe wants to become a world leader in zero-...
# 13  Royal Dutch Shell, Total and Equinor each have...
# 14  The $ 3.6 billion project is expected to deliv...
# 15  US President Joe Biden unveils long-awaited in...
# 16  US carriers are taking a multi-layered approac...
# 17  President Joe Biden wants a federal clean ener...
# 18  Oil traders are setting medium-term greenhouse...
# 19  Hydrocarbons are critical minerals, permeating...
# 20  Taiwan's government is actively pushing agains...
# 21  European oil majors have all committed to the ...
# 22   Exxon Mobil has suffered another natural gas ...
# 23  North American midstream companies are sharpen...
# 24  European majors with aggressive renewables gro...
# 25  North American midstream companies are sharpen...
# 26  Two new funds by US asset management giant Bla...
# 27  Carbon capture is one of many key technologies...
# 28  The US, EU, UK, Canada and Japan dialed up the...
# 29  Hydrogen is likely to only make sense in hard-...
# 30  European countries have published recovery pla...
# 31  Renewables are the cheapest option for new pow...
# 32  Shell plans to cut the number of refineries in...
# 33  Repsol is making its first foray into the fast...
# 34  Interest in nature-based carbon offsetting is ...
# 35  IEA report envisions global nuclear power capa...
# 36  Public companies on both sides of the Atlantic...
# 37  US oil major Chevron faced some stiff sharehol...
# 38  Ministry of Economy, Trade and Industry ( Meti...
# 39  Danish utility Orsted intends to spend over $ ...
# 40  The Biden administration's first annual budget...
# 41  Spanish major Repsol sees the US as the most a...
# 42  Japan's Astomos has signed a deal to buy carbo...
# 43  BP, Equinor, Repsol, Royal Dutch Shell and Tot...
# 44  Oil and gas companies are staring down heighte...
# 45  Drier, hotter weather and robust economic reco...
# 46  BP plans to cut its oil and gas output by 40% ...
# 47  The South Carolina Public Service Commission (...
# 48  The UK government will manage the eventual dec...
# 49  Major US shale producers should hold the line ...

# %%
print(data_chunk["summary"][0])
# Out:
# Qatar Petroleum ( QP) is targeting aggressive cuts in its greenhouse gas emissions as it prepares to launch Phase 2 of its planned 48 million ton per year LNG expansion. The company is also aiming to reduce gas flaring intensity across its upstream facilities.

# %%
print(data_chunk["summary"][1])
# Out:
# Kakrapar-3 is the first of India's 700 megawatt indigenously developed pressurized heavy water reactors ( PHWRs) to reach this milestone. 15 more units of the same design will follow.

# %%
# Import necessary libraries
from transformers import T5ForConditionalGeneration, T5Tokenizer
import pandas as pd
import os
from tqdm import tqdm

# Load the extracted summaries
summary_file_path = 'output/cleantech_media_with_textrank_summaries.csv'
media_summaries_df = pd.read_csv(summary_file_path)
print("\nLoaded extracted summaries:")
print(media_summaries_df.head())

# Initialize the T5 model and tokenizer
model_name = "valhalla/t5-small-qg-hl"
tokenizer = T5Tokenizer.from_pretrained(model_name)
model = T5ForConditionalGeneration.from_pretrained(model_name)


def generate_question(context, max_length=50):
    input_text = f"generate question: {context}"
    input_ids = tokenizer.encode(
        input_text, return_tensors="pt", max_length=512, truncation=True)
    outputs = model.generate(input_ids, max_new_tokens=max_length)
    question = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return question


# Generate QA pairs with batch processing and progress logging
batch_size = 100
qa_pairs = []

for i in tqdm(range(0, len(media_summaries_df), batch_size)):
    batch_df = media_summaries_df.iloc[i:i+batch_size]
    for index, row in batch_df.iterrows():
        summary = row['summary']
        sentences = summary.split('. ')
        # Limit the number of sentences processed
        for sentence in sentences[:5]:
            try:
                question = generate_question(sentence)
                qa_pairs.append({
                    'summary': summary,
                    'question': question,
                    'answer': sentence
                })
            except Exception as e:
                print(f"Error processing summary: {summary}")
                print(e)
                continue

# Ensure the save directory exists
save_dir = 'output/'
os.makedirs(save_dir, exist_ok=True)

# Save the generated QA pairs
qa_pairs_df = pd.DataFrame(qa_pairs)
qa_pairs_file_path = os.path.join(save_dir, 'improved_media_qa_pairs.csv')
qa_pairs_df.to_csv(qa_pairs_file_path, index=False)

print(f"\nGenerated QA pairs saved to {qa_pairs_file_path}")
print("\nGenerated QA pairs:")
print(qa_pairs_df.head())
